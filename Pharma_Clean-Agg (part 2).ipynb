# %% [markdown]
# ### __Pharma Data Cleaner & Aggregator (part 2)__
#
# This file is meant to be a followup to the later portion of the Pharma_Exporatory notebook.  Introduced are the following files:
#
# * fuzzy_prices - containing the drug name comparison information, and price information
# * all_data - containing product, patent, and exclusivity data
#
# This file will merge these two datasets, and further clean/prep them for analysis.
#
# The processes in this notebook, unlike those in the 'Cleaner-Agg part 1' notebook are not available in the Pharma_Exploratory notebook.

# %%
import pandas as pd
# Reading in the CSVs with the python engine will take longer, but will hopefully produce better dtype matching (thus reducing the memory usage)
all_data = pd.read_csv('all_data.csv', engine = 'python')
all_data = all_data.set_index('ndc_description_agg')
all_data.head(3)
# Out:
#                                       Unnamed: 0              ingredient  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                    0              BUDESONIDE
# BETAMETHASONE VALERATE 0.12% TOPICAL           1  BETAMETHASONE VALERATE
# BETAMETHASONE VALERATE 0.12% TOPICAL           2  BETAMETHASONE VALERATE
#
#                                         dosage_form    route  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL           AEROSOL, FOAM   RECTAL
# BETAMETHASONE VALERATE 0.12% TOPICAL  AEROSOL, FOAM  TOPICAL
# BETAMETHASONE VALERATE 0.12% TOPICAL  AEROSOL, FOAM  TOPICAL
#
#                                                   trade_name       strength  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                           UCERIS  2MG/ACTUATION
# BETAMETHASONE VALERATE 0.12% TOPICAL  BETAMETHASONE VALERATE          0.12%
# BETAMETHASONE VALERATE 0.12% TOPICAL  BETAMETHASONE VALERATE          0.12%
#
#                                                 applicant appl_type_x  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL           VALEANT PHARMS INTL           N
# BETAMETHASONE VALERATE 0.12% TOPICAL     PERRIGO UK FINCO           A
# BETAMETHASONE VALERATE 0.12% TOPICAL      RICONPHARMA LLC           A
#
#                                       appl_no  product_no  ... patent_no  \
# ndc_description_agg                                        ...
# UCERIS 2MG/ACTUATION RECTAL            205613           1  ...       NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL    78337           1  ...       NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL   207144           1  ...       NaN
#
#                                      patent_expire_date_text  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                              NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL                     NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL                     NaN
#
#                                      drug_substance_flag drug_product_flag  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                          NaN               NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL                 NaN               NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL                 NaN               NaN
#
#                                      patent_use_code delist_flag  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                      NaN         NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL             NaN         NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL             NaN         NaN
#
#                                      submission_date appl_type  \
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                      NaN       NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL             NaN       NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL             NaN       NaN
#
#                                      exclusivity_code exclusivity_date
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                       NaN              NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL              NaN              NaN
# BETAMETHASONE VALERATE 0.12% TOPICAL              NaN              NaN
#
# [3 rows x 27 columns]

# %%
# Delete more columns to reduce the dataset size (a vast majority of these columns were NaN values)
fuzzy_prices.drop(['Unnamed: 0', 
                   'ndc', 
                   'corresponding_generic_drug_nadac_per_unit',
                   'corresponding_generic_drug_effective_date',
                   'Unnamed: 0.1'], axis = 1, inplace = True)
fuzzy_prices.head(3)

# %%
# Convert to datetime and see the distribution of dates in the 'effective_date' column
pd.to_datetime(fuzzy_prices['effective_date'])
fuzzy_prices['effective_date'].value_counts(dropna = False).sort_values(ascending = False)

# %%
# Attempting to lighten up the dataset further by dropping duplicates
fuzzy_prices.drop_duplicates(keep='first')
fuzzy_prices.info()

# %%
# No real duplicates found (both good and bad news) - compare entry number to info statement at beginning
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58567 entries, 0 to 58566
# Data columns (total 28 columns):
# Unnamed: 0                 58567 non-null int64
# ingredient                 58567 non-null object
# dosage_form                58563 non-null object
# route                      58549 non-null object
# trade_name                 58567 non-null object
# strength                   58500 non-null object
# applicant                  58567 non-null object
# appl_type_x                58567 non-null object
# appl_no                    58567 non-null int64
# product_no                 58567 non-null int64
# te_code                    20466 non-null object
# approval_date              58567 non-null object
# rld                        58567 non-null object
# rs                         58567 non-null object
# type                       58567 non-null object
# applicant_full_name        58567 non-null object
# appl_type_y                23361 non-null object
# patent_no                  23361 non-null object
# patent_expire_date_text    23361 non-null object
# drug_substance_flag        4875 non-null object
# drug_product_flag          11250 non-null object
# patent_use_code            13382 non-null object
# delist_flag                86 non-null object
# submission_date            16648 non-null object
# appl_type                  16206 non-null object
# exclusivity_code           16206 non-null object
# exclusivity_date           16206 non-null object
# ndc_description_agg        58500 non-null object
# dtypes: int64(3), object(25)
# memory usage: 12.5+ MB

# %%
all_data.head()
# Out:
#    Unnamed: 0              ingredient    dosage_form    route  \
# 0           0              BUDESONIDE  AEROSOL, FOAM   RECTAL
# 1           1  BETAMETHASONE VALERATE  AEROSOL, FOAM  TOPICAL
# 2           2  BETAMETHASONE VALERATE  AEROSOL, FOAM  TOPICAL
# 3           3  BETAMETHASONE VALERATE  AEROSOL, FOAM  TOPICAL
# 4           4   CLINDAMYCIN PHOSPHATE  AEROSOL, FOAM  TOPICAL
#
#                trade_name       strength            applicant appl_type_x  \
# 0                  UCERIS  2MG/ACTUATION  VALEANT PHARMS INTL           N
# 1  BETAMETHASONE VALERATE          0.12%     PERRIGO UK FINCO           A
# 2  BETAMETHASONE VALERATE          0.12%      RICONPHARMA LLC           A
# 3  BETAMETHASONE VALERATE          0.12%           TARO PHARM           A
# 4   CLINDAMYCIN PHOSPHATE             1%     PERRIGO UK FINCO           A
#
#    appl_no  product_no  ... patent_expire_date_text drug_substance_flag  \
# 0   205613           1  ...                     NaN                 NaN
# 1    78337           1  ...                     NaN                 NaN
# 2   207144           1  ...                     NaN                 NaN
# 3   208204           1  ...                     NaN                 NaN
# 4    90785           1  ...                     NaN                 NaN
#
#   drug_product_flag patent_use_code delist_flag submission_date appl_type  \
# 0               NaN             NaN         NaN             NaN       NaN
# 1               NaN             NaN         NaN             NaN       NaN
# 2               NaN             NaN         NaN             NaN       NaN
# 3               NaN             NaN         NaN             NaN       NaN
# 4               NaN             NaN         NaN             NaN       NaN
#
#   exclusivity_code exclusivity_date                   ndc_description_agg
# 0              NaN              NaN           UCERIS 2MG/ACTUATION RECTAL
# 1              NaN              NaN  BETAMETHASONE VALERATE 0.12% TOPICAL
# 2              NaN              NaN  BETAMETHASONE VALERATE 0.12% TOPICAL
# 3              NaN              NaN  BETAMETHASONE VALERATE 0.12% TOPICAL
# 4              NaN              NaN      CLINDAMYCIN PHOSPHATE 1% TOPICAL
#
# [5 rows x 28 columns]

# %%
# Change the following columns to datetime dtype
pd.to_datetime(all_data['patent_expire_date_text'])

#From here on, this modification means that these drugs were approved prior to Jan 1, 1982
all_data['approval_date'].replace('Approved Prior to Jan 1, 1982', 'Dec 31, 1981')
# Out:
# ndc_description_agg
# UCERIS 2MG/ACTUATION RECTAL                     Oct 7, 2014
# BETAMETHASONE VALERATE 0.12% TOPICAL           Nov 26, 2012
# BETAMETHASONE VALERATE 0.12% TOPICAL           May 24, 2017
# BETAMETHASONE VALERATE 0.12% TOPICAL           May 24, 2017
# CLINDAMYCIN PHOSPHATE 1% TOPICAL               Mar 31, 2010
# CLOBETASOL PROPIONATE 0.05% TOPICAL            Feb 15, 2019
# CLOBETASOL PROPIONATE 0.05% TOPICAL            Jul 31, 2017
# CLOBETASOL PROPIONATE 0.05% TOPICAL            Mar 10, 2008
# CLOBETASOL PROPIONATE 0.05% TOPICAL            Aug 14, 2012
# CLOBETASOL PROPIONATE 0.05% TOPICAL             Oct 4, 2018
# ECOZA 1% TOPICAL                               Oct 24, 2013
# ENSTILAR 0.064%;0.005% TOPICAL                 Oct 16, 2015
# ENSTILAR 0.064%;0.005% TOPICAL                 Oct 16, 2015
# ENSTILAR 0.064%;0.005% TOPICAL                 Oct 16, 2015
# EVOCLIN 1% TOPICAL                             Oct 22, 2004
# EVOCLIN 1% TOPICAL                             Oct 22, 2004
# EXTINA 2% TOPICAL                              Jun 12, 2007
# FABIOR 0.1% TOPICAL                            May 11, 2012
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# FINACEA 15% TOPICAL                            Jul 29, 2015
# HALOBETASOL PROPIONATE 0.05% TOPICAL           May 24, 2018
# KETOCONAZOLE 2% TOPICAL                        Aug 25, 2011
# LUXIQ 0.12% TOPICAL                            Feb 28, 1999
#                                                    ...
# NICOTINE POLACRILEX EQ 2MG BASE ORAL           Jul 10, 2009
# NICOTINE POLACRILEX EQ 2MG BASE ORAL            Oct 9, 2012
# NICOTINE POLACRILEX EQ 4MG BASE ORAL           Jan 31, 2006
# NICOTINE POLACRILEX EQ 4MG BASE ORAL           Jul 10, 2009
# NICOTINE POLACRILEX EQ 4MG BASE ORAL           Jul 10, 2009
# NICOTINE POLACRILEX EQ 4MG BASE ORAL            Oct 9, 2012
# NICOTINE POLACRILEX EQ 2MG BASE ORAL            Feb 7, 2019
# NICOTINE POLACRILEX EQ 4MG BASE ORAL            Feb 7, 2019
# NICOTINE POLACRILEX EQ 2MG BASE ORAL           Jun 26, 2018
# NICOTINE POLACRILEX EQ 4MG BASE ORAL           Jun 26, 2018
# NICOTINE POLACRILEX EQ 2MG BASE ORAL            Jul 2, 2018
# NICOTINE POLACRILEX EQ 4MG BASE ORAL            Jul 2, 2018
# ACTIQ EQ 0.2MG BASE TRANSMUCOSAL                Nov 4, 1998
# ACTIQ EQ 0.4MG BASE TRANSMUCOSAL                Nov 4, 1998
# ACTIQ EQ 0.6MG BASE TRANSMUCOSAL                Nov 4, 1998
# ACTIQ EQ 0.8MG BASE TRANSMUCOSAL                Nov 4, 1998
# ACTIQ EQ 1.2MG BASE TRANSMUCOSAL                Nov 4, 1998
# ACTIQ EQ 1.6MG BASE TRANSMUCOSAL                Nov 4, 1998
# FENTANYL CITRATE EQ 0.2MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.4MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.6MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.8MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 1.2MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 1.6MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.2MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.4MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.6MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 0.8MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 1.2MG BASE TRANSMUCOSAL    Oct 30, 2009
# FENTANYL CITRATE EQ 1.6MG BASE TRANSMUCOSAL    Oct 30, 2009
# Name: approval_date, Length: 58567, dtype: object

# %%
# Several columns to drop
all_data.drop(['Unnamed: 0', 
               'appl_no',
               'drug_substance_flag',
               'applicant'], axis = 1, inplace = True)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58567 entries, 0 to 58566
# Data columns (total 24 columns):
# ingredient                 58567 non-null object
# dosage_form                58563 non-null object
# route                      58549 non-null object
# trade_name                 58567 non-null object
# strength                   58500 non-null object
# appl_type_x                58567 non-null object
# product_no                 58567 non-null int64
# te_code                    20466 non-null object
# approval_date              58567 non-null object
# rld                        58567 non-null object
# rs                         58567 non-null object
# type                       58567 non-null object
# applicant_full_name        58567 non-null object
# appl_type_y                23361 non-null object
# patent_no                  23361 non-null object
# patent_expire_date_text    23361 non-null object
# drug_product_flag          11250 non-null object
# patent_use_code            13382 non-null object
# delist_flag                86 non-null object
# submission_date            16648 non-null object
# appl_type                  16206 non-null object
# exclusivity_code           16206 non-null object
# exclusivity_date           16206 non-null object
# ndc_description_agg        58500 non-null object
# dtypes: int64(1), object(23)
# memory usage: 10.7+ MB

# %% [markdown]
# #### __Merging time:__
# Seeing as I was able to reduce the price dataset by almost half, I'll try and merge the two datasets again.  I'll merge 'right' this time because I want to keep as much of the patent data as possible.
#
# <b>Note to self:</b> you may want to come back and merge by 'outer' so that you can retain as much price info as possible and extrapolate any missing patent data for drugs that have prices but no patent dates.
#
# Originally, I opened the fuzzy_prices file at the top cleaned it, and then tried to priocess it here at the bottom of the notebook. I've found, however, that chunking and processing the CSV as it is read in leads to far fewer errors with my machine's limited memory.

# %%
# Chunk, prepare, and merge the fuzzy_prices file with the all_data file
for chunk in pd.read_csv('fuzzy_prices.csv', chunksize = 25e6, engine = 'python'):
    chunk.set_index('ndc_description_agg')
    chunk.drop(['Unnamed: 0', 
                       'ndc', 
                       'corresponding_generic_drug_nadac_per_unit',
                       'corresponding_generic_drug_effective_date',
                       'Unnamed: 0.1'], axis = 1, inplace = True)
    chunk.head(3)

    # Convert to datetime and see the distribution of dates in the 'effective_date' column
    pd.to_datetime(chunk['effective_date'])
    chunk['effective_date'].value_counts(dropna = False).sort_values(ascending = False)

    # Attempting to lighten up the dataset further by dropping duplicates
    chunk.drop_duplicates(keep='first')
    chunk.info()
    merged_all = chunk.join(all_data, how = 'outer')
    merged_all.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9978725 entries, 0 to 9978724
# Data columns (total 9 columns):
# ndc_description                    object
# cost_per_unit_usd                  float64
# effective_date                     object
# pricing_unit                       object
# over_the_counter                   object
# classification_for_rate_setting    object
# as_of_date                         object
# ndc_description_agg                object
# score                              int64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 685.2+ MB

# %%
merged_all.head()
# Out:
#           ndc_description  cost_per_unit_usd effective_date pricing_unit  \
# 0  IBUPROFEN 200MG TABLET            0.02991     2018-11-21           EA
# 1  IBUPROFEN 200MG TABLET            0.02991     2018-11-21           EA
# 2  IBUPROFEN 200MG TABLET            0.02991     2018-11-21           EA
# 3  IBUPROFEN 200MG TABLET            0.02991     2018-11-21           EA
# 4  IBUPROFEN 200MG TABLET            0.02991     2018-11-21           EA
#
#   over_the_counter classification_for_rate_setting  as_of_date  \
# 0                Y                               G  2018-12-12
# 1                Y                               G  2018-12-12
# 2                Y                               G  2018-12-12
# 3                Y                               G  2018-12-12
# 4                Y                               G  2018-12-12
#
#     ndc_description_agg  score ingredient  ... appl_type_y patent_no  \
# 0  IBUPROFEN 200MG ORAL   86.0        NaN  ...         NaN       NaN
# 1  IBUPROFEN 200MG ORAL   86.0        NaN  ...         NaN       NaN
# 2  IBUPROFEN 200MG ORAL   86.0        NaN  ...         NaN       NaN
# 3  IBUPROFEN 200MG ORAL   86.0        NaN  ...         NaN       NaN
# 4  IBUPROFEN 200MG ORAL   86.0        NaN  ...         NaN       NaN
#
#   patent_expire_date_text drug_product_flag patent_use_code  delist_flag  \
# 0                     NaN               NaN             NaN          NaN
# 1                     NaN               NaN             NaN          NaN
# 2                     NaN               NaN             NaN          NaN
# 3                     NaN               NaN             NaN          NaN
# 4                     NaN               NaN             NaN          NaN
#
#   submission_date appl_type exclusivity_code exclusivity_date
# 0             NaN       NaN              NaN              NaN
# 1             NaN       NaN              NaN              NaN
# 2             NaN       NaN              NaN              NaN
# 3             NaN       NaN              NaN              NaN
# 4             NaN       NaN              NaN              NaN
#
# [5 rows x 32 columns]

# %%
# Export the merged file
merged_all = merged_all.to_csv('merged_all.csv')

# %% [markdown]
# ### __Yet another Dask attempt__

# %%
# Attempting dask again!
from dask import dataframe as dd 
from dask.distributed import Client, LocalCluster

# Initiate the client!
client = Client(n_workers = 1, 
                threads_per_worker = 4, 
                processes = False, 
               memory_limit = '14GB', 
               scheduler_port = 0, 
               silence_logs = True, 
               diagnostics_port = 0)
client

# %%
# Start the merger
merged_all_ddf = client.submit(pd.merge(fuzzy_prices, all_data, on=['ndc_description_agg'], how = 'right').compute())

# %%
merged_all_ddf.describe()
