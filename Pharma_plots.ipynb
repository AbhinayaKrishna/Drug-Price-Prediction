# %% [markdown]
# # __Pharma Exploratory Plots__
#
# __Questions to answer:__
# * What is the correlation among variables (particularly drug prices and patent application/expiration dates)?
# * What is the average patent term?
# * What does the patent application date distribution look like?
# * Generic vs. Brand drug prices
# * Price by active ingredient (correlation & sorting)
# * Drug price over time
# * What is the average value of a patent?
# * What is the average value of exclusivity?
#
#
# __Conclusions:__
# *

# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
# Read in our data
df = pd.read_csv('merged_all.csv', engine = 'python')
df.describe(include = 'all')
# Out:
#                   Unnamed: 0                 ndc_description  \
# count               10037225                         9978725
# unique               9993213                             733
# top     IMBRUVICA 140MG ORAL  LOSARTAN POTASSIUM 50MG TABLET
# freq                     822                          211094
# mean                     NaN                             NaN
# std                      NaN                             NaN
# min                      NaN                             NaN
# 25%                      NaN                             NaN
# 50%                      NaN                             NaN
# 75%                      NaN                             NaN
# max                      NaN                             NaN
#
#         cost_per_unit_usd effective_date pricing_unit over_the_counter  \
# count        9.978725e+06        9978725      9978725          9978725
# unique                NaN            416            3                2
# top                   NaN     2018-10-17           EA                N
# freq                  NaN         195113      9601448          9659263
# mean         8.529105e-01            NaN          NaN              NaN
# std          1.521254e+01            NaN          NaN              NaN
# min          8.120000e-03            NaN          NaN              NaN
# 25%          4.261000e-02            NaN          NaN              NaN
# 50%          1.084000e-01            NaN          NaN              NaN
# 75%          2.861700e-01            NaN          NaN              NaN
# max          2.180789e+03            NaN          NaN              NaN
#
#        classification_for_rate_setting  as_of_date  \
# count                          9978725     9978725
# unique                               3         296
# top                                  G  2018-08-29
# freq                           9943969       38637
# mean                               NaN         NaN
# std                                NaN         NaN
# min                                NaN         NaN
# 25%                                NaN         NaN
# 50%                                NaN         NaN
# 75%                                NaN         NaN
# max                                NaN         NaN
#
#                                       ndc_description_agg         score  ...  \
# count                                             9978725  9.978725e+06  ...
# unique                                                618           NaN  ...
# top     AMLODIPINE BESYLATE AND BENAZEPRIL HYDROCHLORI...           NaN  ...
# freq                                               454314           NaN  ...
# mean                                                  NaN  8.763332e+01  ...
# std                                                   NaN  2.293836e+00  ...
# min                                                   NaN  8.600000e+01  ...
# 25%                                                   NaN  8.600000e+01  ...
# 50%                                                   NaN  8.700000e+01  ...
# 75%                                                   NaN  8.800000e+01  ...
# max                                                   NaN  1.000000e+02  ...
#
#        appl_type_y patent_no patent_expire_date_text drug_product_flag  \
# count        23361     23361                   23361             11250
# unique           1      4743                    2143                 1
# top              N   8835443            Dec 28, 2026                 Y
# freq         23361       208                     633             11250
# mean           NaN       NaN                     NaN               NaN
# std            NaN       NaN                     NaN               NaN
# min            NaN       NaN                     NaN               NaN
# 25%            NaN       NaN                     NaN               NaN
# 50%            NaN       NaN                     NaN               NaN
# 75%            NaN       NaN                     NaN               NaN
# max            NaN       NaN                     NaN               NaN
#
#        patent_use_code delist_flag  submission_date appl_type  \
# count            13382          86            16648     16206
# unique            1637           1             1407         2
# top              U-493           Y     Sep 15, 2017         N
# freq               214          86              338     16167
# mean               NaN         NaN              NaN       NaN
# std                NaN         NaN              NaN       NaN
# min                NaN         NaN              NaN       NaN
# 25%                NaN         NaN              NaN       NaN
# 50%                NaN         NaN              NaN       NaN
# 75%                NaN         NaN              NaN       NaN
# max                NaN         NaN              NaN       NaN
#
#        exclusivity_code exclusivity_date
# count             16206            16206
# unique              403              593
# top                 NCE     Jul 27, 2020
# freq               2341              418
# mean                NaN              NaN
# std                 NaN              NaN
# min                 NaN              NaN
# 25%                 NaN              NaN
# 50%                 NaN              NaN
# 75%                 NaN              NaN
# max                 NaN              NaN
#
# [11 rows x 33 columns]

# %% [markdown]
# __Interesting insights from the numbers above:__
# * The average cost per unit is $0.85.  Units are most often 'each', and refer to tablets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10037292 entries, 0 to 10037291
# Data columns (total 33 columns):
# Unnamed: 0                         object
# ndc_description                    object
# cost_per_unit_usd                  float64
# effective_date                     object
# pricing_unit                       object
# over_the_counter                   object
# classification_for_rate_setting    object
# as_of_date                         object
# ndc_description_agg                object
# score                              float64
# ingredient                         object
# dosage_form                        object
# route                              object
# trade_name                         object
# strength                           object
# appl_type_x                        object
# product_no                         float64
# te_code                            object
# approval_date                      object
# rld                                object
# rs                                 object
# type                               object
# applicant_full_name                object
# appl_type_y                        object
# patent_no                          object
# patent_expire_date_text            object
# drug_product_flag                  object
# patent_use_code                    object
# delist_flag                        object
# submission_date                    object
# appl_type                          object
# exclusivity_code                   object
# exclusivity_date                   object
# dtypes: float64(3), object(30)
# memory usage: 2.5+ GB

# %%
df.head(5)
# Out:
#   Unnamed: 0         ndc_description  cost_per_unit_usd effective_date  \
# 0          0  IBUPROFEN 200MG TABLET            0.02991     2018-11-21
# 1          1  IBUPROFEN 200MG TABLET            0.02991     2018-11-21
# 2          2  IBUPROFEN 200MG TABLET            0.02991     2018-11-21
# 3          3  IBUPROFEN 200MG TABLET            0.02991     2018-11-21
# 4          4  IBUPROFEN 200MG TABLET            0.02991     2018-11-21
#
#   pricing_unit over_the_counter classification_for_rate_setting  as_of_date  \
# 0           EA                Y                               G  2018-12-12
# 1           EA                Y                               G  2018-12-12
# 2           EA                Y                               G  2018-12-12
# 3           EA                Y                               G  2018-12-12
# 4           EA                Y                               G  2018-12-12
#
#     ndc_description_agg  score  ... appl_type_y patent_no  \
# 0  IBUPROFEN 200MG ORAL   86.0  ...         NaN       NaN
# 1  IBUPROFEN 200MG ORAL   86.0  ...         NaN       NaN
# 2  IBUPROFEN 200MG ORAL   86.0  ...         NaN       NaN
# 3  IBUPROFEN 200MG ORAL   86.0  ...         NaN       NaN
# 4  IBUPROFEN 200MG ORAL   86.0  ...         NaN       NaN
#
#   patent_expire_date_text drug_product_flag patent_use_code delist_flag  \
# 0                     NaN               NaN             NaN         NaN
# 1                     NaN               NaN             NaN         NaN
# 2                     NaN               NaN             NaN         NaN
# 3                     NaN               NaN             NaN         NaN
# 4                     NaN               NaN             NaN         NaN
#
#    submission_date appl_type exclusivity_code exclusivity_date
# 0              NaN       NaN              NaN              NaN
# 1              NaN       NaN              NaN              NaN
# 2              NaN       NaN              NaN              NaN
# 3              NaN       NaN              NaN              NaN
# 4              NaN       NaN              NaN              NaN
#
# [5 rows x 33 columns]

# %%
# df.drop(['Unnamed: 0', 'drug_product_flag','delist_flag','patent_use_code'], axis = 1, inplace = True)
# Create a subset of the 10 most interesting columns
df_sub = df[['ndc_description', 
             'cost_per_unit_usd', 
             'effective_date', 
             'over_the_counter', 
             'classification_for_rate_setting',
             'submission_date',
             'patent_expire_date_text',
             'applicant_full_name',
             'approval_date',
             'exclusivity_date']]

# %%
# del df_sub
# del df
# import gc
# gc.collect()

# %%
# Not working (yet)
# df_sub['submission_date'] = pd.to_datetime(df_sub.loc[df_sub['submission_date']], format = '%b %d, %Y')
# df_sub['exclusivity_date'] = pd.to_datetime(df_sub.loc[df_sub['exclusivity_date']],format = '%b %d, %Y')
# df_sub['patent_expire_date_text'] = pd.to_datetime(df_sub.loc[df_sub['patent_expire_date_text']],format = '%b %d, %Y')

# %%
df_sub_patents = df[df['cost_per_unit_usd'].notnull()][:10000]
df_sub_patents.describe(include = 'all')
# Out:
#        Unnamed: 0         ndc_description  cost_per_unit_usd effective_date  \
# count       10000                   10000       10000.000000          10000
# unique      10000                       1                NaN              8
# top          6029  IBUPROFEN 200MG TABLET                NaN     2019-04-17
# freq            1                   10000                NaN           2160
# mean          NaN                     NaN           0.029798            NaN
# std           NaN                     NaN           0.001143            NaN
# min           NaN                     NaN           0.028430            NaN
# 25%           NaN                     NaN           0.028700            NaN
# 50%           NaN                     NaN           0.029340            NaN
# 75%           NaN                     NaN           0.030830            NaN
# max           NaN                     NaN           0.031450            NaN
#
#        pricing_unit over_the_counter classification_for_rate_setting  \
# count         10000            10000                           10000
# unique            1                1                               1
# top              EA                Y                               G
# freq          10000            10000                           10000
# mean            NaN              NaN                             NaN
# std             NaN              NaN                             NaN
# min             NaN              NaN                             NaN
# 25%             NaN              NaN                             NaN
# 50%             NaN              NaN                             NaN
# 75%             NaN              NaN                             NaN
# max             NaN              NaN                             NaN
#
#         as_of_date   ndc_description_agg    score  ...  appl_type_y  \
# count        10000                 10000  10000.0  ...          0.0
# unique          25                     1      NaN  ...          0.0
# top     2019-05-22  IBUPROFEN 200MG ORAL      NaN  ...          NaN
# freq           450                 10000      NaN  ...          NaN
# mean           NaN                   NaN     86.0  ...          NaN
# std            NaN                   NaN      0.0  ...          NaN
# min            NaN                   NaN     86.0  ...          NaN
# 25%            NaN                   NaN     86.0  ...          NaN
# 50%            NaN                   NaN     86.0  ...          NaN
# 75%            NaN                   NaN     86.0  ...          NaN
# max            NaN                   NaN     86.0  ...          NaN
#
#         patent_no  patent_expire_date_text  drug_product_flag  \
# count         0.0                      0.0                0.0
# unique        0.0                      0.0                0.0
# top           NaN                      NaN                NaN
# freq          NaN                      NaN                NaN
# mean          NaN                      NaN                NaN
# std           NaN                      NaN                NaN
# min           NaN                      NaN                NaN
# 25%           NaN                      NaN                NaN
# 50%           NaN                      NaN                NaN
# 75%           NaN                      NaN                NaN
# max           NaN                      NaN                NaN
#
#         patent_use_code  delist_flag  submission_date  appl_type  \
# count               0.0          0.0              0.0        0.0
# unique              0.0          0.0              0.0        0.0
# top                 NaN          NaN              NaN        NaN
# freq                NaN          NaN              NaN        NaN
# mean                NaN          NaN              NaN        NaN
# std                 NaN          NaN              NaN        NaN
# min                 NaN          NaN              NaN        NaN
# 25%                 NaN          NaN              NaN        NaN
# 50%                 NaN          NaN              NaN        NaN
# 75%                 NaN          NaN              NaN        NaN
# max                 NaN          NaN              NaN        NaN
#
#         exclusivity_code  exclusivity_date
# count                0.0               0.0
# unique               0.0               0.0
# top                  NaN               NaN
# freq                 NaN               NaN
# mean                 NaN               NaN
# std                  NaN               NaN
# min                  NaN               NaN
# 25%                  NaN               NaN
# 50%                  NaN               NaN
# 75%                  NaN               NaN
# max                  NaN               NaN
#
# [11 rows x 33 columns]

# %%
df_sub_patents['patent_no'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-55b6b42081c2> in <module>
# ----> 1 df_sub_patents.value_counts(dropna = False)
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_sub_patents, alpha = 0.2, figsize = (10,10), diagonal = 'kde')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-9d611a7a67fd> in <module>
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(df_sub_patents, alpha = 0.2, figsize = (10,10), diagonal = 'kde')
#
# C:\Anaconda\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      76     for a in df.columns:
#      77         values = df[a].values[mask[a].values]
# ---> 78         rmin_, rmax_ = np.min(values), np.max(values)
#      79         rdelta_ext = (rmax_ - rmin_) * range_padding / 2.
#      80         boundaries_list.append((rmin_ - rdelta_ext, rmax_ + rdelta_ext))
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# C:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
import seaborn as sns
sns.set(style = 'ticks')

sns.pairplot(df_sub_patents)

# %%
from scipy.stats import chisquare
chisquare(df)

# %%
import numpy as np
import matplotlib.pyplot as plt
# Compute the correlation matrix
corr = df_sub.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
